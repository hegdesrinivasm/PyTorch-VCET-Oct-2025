# %%
import torch
from matplotlib import pyplot as plt
import numpy as np

# %%
#Tensor
x = np.array([1, 2, 3])
y = np.array([1, 2, 3])
z = np.array([1, 2, 3])
print(x)
# Out:
# [1 2 3]

# %%
tensor = torch.tensor([x, y, z])
# Out:
# /var/folders/_7/0q3t2l550t1b9zhg3_2lqc2w0000gn/T/ipykernel_45453/3150355401.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:256.)
#   tensor = torch.tensor([x, y, z])

# %%
print(tensor)
# Out:
# tensor([[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]])

# %%
tensor.shape
# Out:
# torch.Size([3, 3])

# %%
x = np.array([[[1, 2, 3], [1, 2, 3], [1, 2, 3]], [[1, 2, 3], [1, 2, 3], [1, 2, 3]], [[1, 2, 3], [1, 2, 3], [1, 2, 3]]])

# %%
x = torch.tensor(x)
x.shape
# Out:
# torch.Size([3, 3, 3])

# %%
x
# Out:
# tensor([[[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]],
#
#         [[1, 2, 3],
#          [1, 2, 3],
#          [1, 2, 3]]])

# %% [markdown]
# ### Reshaping:
# Tensors can be reshaped using the 'reshape' method -- but only if the total number of elements remains the same.

# %%
x.reshape(9, 3)
# Out:
# tensor([[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]])

# %%
a = np.array([[[1,2], [1, 2]], [[1, 2], [1, 2]]])
a = torch.tensor(a)
a.shape
# Out:
# torch.Size([2, 2, 2])

# %%
a.reshape(4, 2)
# Out:
# tensor([[1, 2],
#         [1, 2],
#         [1, 2],
#         [1, 2]])

# %%
x = tensor.to(device = "cpu")

# %%
x * y
# Out:
# /var/folders/_7/0q3t2l550t1b9zhg3_2lqc2w0000gn/T/ipykernel_45453/4205270810.py:1: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   x * y
# tensor([[1, 4, 9],
#         [1, 4, 9],
#         [1, 4, 9]])

# %%
x = torch.rand(255, 255, 3)

# %%
x*255
# Out:
# tensor([[[  5.6950,  88.8004, 116.2478],
#          [215.8046, 113.0793, 217.2474],
#          [206.9009,  67.3936,  34.4833],
#          ...,
#          [106.2112, 232.0470, 208.9492],
#          [226.7367,  38.7712, 180.6293],
#          [181.0940,  60.7055, 235.2457]],
#
#         [[158.6645,  70.1855, 206.4851],
#          [ 82.7774,  29.3345, 103.0622],
#          [ 34.6238,  45.8648, 117.8970],
#          ...,
#          [ 22.6504,  30.2705,  16.3234],
#          [138.8040,  97.0349, 139.0112],
#          [194.5260, 134.0475, 170.7170]],
#
#         [[250.8393, 202.0378,  63.3397],
#          [ 71.2762, 176.3217,  33.0682],
#          [ 11.9156, 118.2570, 113.4106],
#          ...,
#          [ 24.6093, 220.0937, 171.7695],
#          [ 36.1846, 224.6739, 128.5588],
#          [160.3349, 111.9076,  67.6269]],
#
#         ...,
#
#         [[ 89.5639, 149.3184, 112.8943],
#          [183.1132, 175.5981,  95.8364],
#          [146.8177,  53.9996, 186.0051],
#          ...,
# ...

# %%
x.device
#Tells which device the tensor is running on
# Out:
# device(type='cpu')

# %%
plt.imshow(x)
